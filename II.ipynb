# %%
# !pip install yfinance
# !pip install matplotlib
# !pip install pandas==1.3.3
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      -------------------- ------------------- 1.6/3.0 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 4.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for peewee: filename=peewee-3.17.9-py3-none-any.whl size=139127 sha256=2af4c79c965a02964ce1cbebbc443fa9f18537362a2be42cd8003d24a5772735
# ...

# %%
tesla_share_price_data = tesla.history(period="max")

# %%
tesla_share_price_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
tesla_revenue = tesla.history(period="max")

# %%
tesla_share_price_data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-03-28 00:00:00-04:00  275.579987  276.100006  260.570007  263.549988
# 2025-03-31 00:00:00-04:00  249.309998  260.559998  243.360001  259.160004
# 2025-04-01 00:00:00-04:00  263.799988  277.450012  259.250000  268.459991
# 2025-04-02 00:00:00-04:00  254.600006  284.989990  251.270004  282.760010
# 2025-04-03 00:00:00-04:00  265.290009  276.299988  261.510010  267.279999
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-03-28 00:00:00-04:00  123809400        0.0           0.0
# 2025-03-31 00:00:00-04:00  134008900        0.0           0.0
# 2025-04-01 00:00:00-04:00  146486900        0.0           0.0
# 2025-04-02 00:00:00-04:00  212787800        0.0           0.0
# 2025-04-03 00:00:00-04:00  135752400        0.0           0.0

# %%
gamestop = yf.Ticker("GME")

# %%
gamestop_share_price_data = gamestop.history(period="max")

# %%
gamestop_share_price_data.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620128  1.693350  1.603296  1.691666  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666417  1.666417  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %%
gamestop_revenue = gamestop.history(period="max")

# %%
gamestop_revenue.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2025-03-28 00:00:00-04:00  21.889999  22.790001  21.700001  21.730000
# 2025-03-31 00:00:00-04:00  21.400000  22.629999  20.730000  22.320000
# 2025-04-01 00:00:00-04:00  22.760000  23.250000  21.950001  22.610001
# 2025-04-02 00:00:00-04:00  22.490000  23.020000  22.250000  22.690001
# 2025-04-03 00:00:00-04:00  21.600000  21.780001  21.080000  21.100000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-03-28 00:00:00-04:00  44771700        0.0           0.0
# 2025-03-31 00:00:00-04:00  16147900        0.0           0.0
# 2025-04-01 00:00:00-04:00  14435300        0.0           0.0
# 2025-04-02 00:00:00-04:00  10965100        0.0           0.0
# 2025-04-03 00:00:00-04:00  10997100        0.0           0.0

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# Using the function to graph Tesla stock data
make_graph(tesla_share_price_data, "Tesla Stock Price History")

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# Using the function to graph Tesla stock data
make_graph(gamestop_share_price_data, "Gamestop Stock Price History")
